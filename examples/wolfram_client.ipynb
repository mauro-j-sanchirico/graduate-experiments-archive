# %%
# Wolfram Language Imports
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl, wlexpr
session = WolframLanguageSession()

# Display Latex
from IPython.display import display, Math

# %%
integrand = wlexpr('x^3 * Csch[a*x]')
intvar = wlexpr('x')
integral = session.evaluate(wl.Integrate(integrand, intvar))
tex_integral = session.evaluate(wl.ToString(wl.TeXForm(integral)))
display(Math(tex_integral))
# Out:
# Socket exception: Socket operation aborted.
# Failed to start.
# ---------------------------------------------------------------------------
# SocketAborted                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\kernelcontroller.py in _kernel_start(self)
#     436                 timeout=self.get_parameter("STARTUP_TIMEOUT"),
# --> 437                 abort_event=_StartEvent(self.kernel_proc, self.trigger_termination_requested),
#     438             )
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\zmqsocket.py in recv_abortable(socket, timeout, abort_check_period, abort_event, **kwargs)
#      49                     if abort_event.is_set():
# ---> 50                         raise SocketAborted("Socket operation aborted.")
#      51                 if timeout and (time.perf_counter() - start > timeout):
#
# SocketAborted: Socket operation aborted.
#
# During handling of the above exception, another exception occurred:
#
# WolframKernelException                    Traceback (most recent call last)
# <ipython-input-2-28cf7f1a3c8e> in <module>
#       1 integrand = wlexpr('x^3 * Csch[a*x]')
#       2 intvar = wlexpr('x')
# ----> 3 integral = session.evaluate(wl.Integrate(integrand, intvar))
#       4 tex_integral = session.evaluate(wl.ToString(wl.TeXForm(integral)))
#       5 display(Math(tex_integral))
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\localsession.py in evaluate(self, expr, **kwargs)
#     257
#     258     def evaluate(self, expr, **kwargs):
# --> 259         result = self.evaluate_wrap(expr, **kwargs)
#     260         self.log_message_from_result(result)
#     261         return result.get()
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\localsession.py in evaluate_wrap(self, expr, **kwargs)
#     254
#     255     def evaluate_wrap(self, expr, **kwargs):
# --> 256         return self.evaluate_wrap_future(expr, **kwargs).result()
#     257
#     258     def evaluate(self, expr, **kwargs):
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\localsession.py in evaluate_wrap_future(self, expr, **kwargs)
#     250         See :func:`~wolframclient.evaluation.WolframLanguageSession.evaluate_wrap`.
#     251         """
# --> 252         self.ensure_started()
#     253         return self.do_evaluate_future(expr, **kwargs)
#     254
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\localsession.py in ensure_started(self)
#     201     def ensure_started(self):
#     202         if not self.started:
# --> 203             self.start(block=True, timeout=None)
#     204         if self.stopped:
#     205             self.restart()
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\localsession.py in start(self, block, timeout)
#     155                 self.terminate()
#     156             finally:
# --> 157                 raise e
#     158
#     159     def start_future(self):
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\localsession.py in start(self, block, timeout)
#     150             future = self.start_future()
#     151             if future and block:
# --> 152                 future.result(timeout=timeout)
#     153         except Exception as e:
#     154             try:
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     433                 raise CancelledError()
#     434             elif self._state == FINISHED:
# --> 435                 return self.__get_result()
#     436             else:
#     437                 raise TimeoutError()
#
# ~\anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     382     def __get_result(self):
#     383         if self._exception:
# --> 384             raise self._exception
#     385         else:
#     386             return self._result
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\kernelcontroller.py in run(self)
#     525             # Kernel start requested.
#     526             if payload is self.START:
# --> 527                 self._safe_kernel_start()
#     528                 future.set_result(True)
#     529                 future = None
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\kernelcontroller.py in _safe_kernel_start(self)
#     364                 self._kernel_terminate()
#     365             finally:
# --> 366                 raise e
#     367
#     368     _KERNEL_OK = b"OK"
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\kernelcontroller.py in _safe_kernel_start(self)
#     358         """ Start a kernel. If something went wrong, clean-up resources that may have been created. """
#     359         try:
# --> 360             self._kernel_start()
#     361         except Exception as e:
#     362             logger.warning("Failed to start.")
#
# ~\anaconda3\lib\site-packages\wolframclient\evaluation\kernel\kernelcontroller.py in _kernel_start(self)
#     454             logger.warning("Socket exception: %s", se)
#     455             raise WolframKernelException(
# --> 456                 "Failed to communicate with kernel: %s." % self.kernel
#     457             )
#     458
#
# WolframKernelException: Failed to communicate with kernel: C:\Program Files\Wolfram Research\Wolfram Engine\12.1\WolframKernel.exe.
