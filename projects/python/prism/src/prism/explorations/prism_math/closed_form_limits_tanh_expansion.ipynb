# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from prism.prism_math.activation_coefs import get_alpha_coefs, compute_lambda_csch_mp
from prism.prism_math.polynomials import polyval_cpu

from mpmath import exp, betainc, bernoulli, csch, factorial, im, hyper, re, sin, zeta
from mpmath import mp
from mpmath import pi, inf, j
from mpmath import quad

# %%
m = 3
compute_lambda_csch_mp(a=pi/2, j=2*m+1, xi=0.000000000000001)
# Out:
# mpf('-272.00000000000011')

# %%
(-1)**(m+1) * 2**(2*m+1) * (4**(m+1) - 1) / (m+1) * bernoulli(2*m+2)
# Out:
# mpf('-272.0')

# %%
j = 2*m+1
- (2**(j+2) - 2) * factorial(j) / pi**(j+1) * zeta(j+1)
# Out:
# mpf('-272.00000000000011')
