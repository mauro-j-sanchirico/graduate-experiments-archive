# %% [markdown]
# # FFNN Visual Tests

# %%
# %load_ext autoreload
# %autoreload 2

from prism.networks.ffnn import visual_test_fit_infer
from prism.networks.ffnn import visual_test_save_load
from prism.networks.ffnn import visual_test_numpy_equivalence_relu
from prism.networks.ffnn import visual_test_numpy_equivalence_tanh

# %%
visual_test_fit_infer()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 23.758056; bad epochs = 0; good epochs = 0
# [2] running loss: 43.696237; bad epochs = 1; good epochs = 0
# [3] running loss: 55.786193; bad epochs = 2; good epochs = 0
# [4] running loss: 36.593665; bad epochs = 3; good epochs = 0
# [5] running loss: 36.895585; bad epochs = 0; good epochs = 1
# Finished Training.

# %%
visual_test_save_load()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 23.679993; bad epochs = 0; good epochs = 0
# [2] running loss: 51.660960; bad epochs = 1; good epochs = 0
# [3] running loss: 51.067822; bad epochs = 2; good epochs = 0
# [4] running loss: 37.651472; bad epochs = 0; good epochs = 1
# [5] running loss: 34.498205; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# Finished Training.

# %%
visual_test_numpy_equivalence_relu()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 21.568716; bad epochs = 0; good epochs = 0
# [2] running loss: 46.778766; bad epochs = 1; good epochs = 0
# [3] running loss: 45.517877; bad epochs = 2; good epochs = 0
# [4] running loss: 30.622855; bad epochs = 0; good epochs = 1
# [5] running loss: 28.216041; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# Finished Training.

# %%
visual_test_numpy_equivalence_tanh()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 20.992658; bad epochs = 0; good epochs = 0
# [2] running loss: 37.514826; bad epochs = 1; good epochs = 0
# [3] running loss: 44.754808; bad epochs = 2; good epochs = 0
# [4] running loss: 41.582186; bad epochs = 3; good epochs = 0
# [5] running loss: 44.087372; bad epochs = 0; good epochs = 1
# Finished Training.
