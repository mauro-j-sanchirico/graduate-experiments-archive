# %% [markdown]
# # FFNN Visual Tests

# %%
# %load_ext autoreload
# %autoreload 2

from prism.networks.ffnn3 import visual_test_fit_infer
from prism.networks.ffnn3 import visual_test_save_load
from prism.networks.ffnn3 import visual_test_numpy_equivalence_relu
from prism.networks.ffnn3 import visual_test_numpy_equivalence_tanh

# %%
visual_test_fit_infer()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 119.499854; bad epochs = 0; good epochs = 0
# [2] running loss: 94.670788; bad epochs = 1; good epochs = 0
# [3] running loss: 85.822672; bad epochs = 0; good epochs = 1
# [4] running loss: 74.723547; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# [5] running loss: 54.450775; bad epochs = 0; good epochs = 0
# Finished Training.

# %%
visual_test_save_load()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 130.945797; bad epochs = 0; good epochs = 0
# [2] running loss: 115.218055; bad epochs = 1; good epochs = 0
# [3] running loss: 86.907791; bad epochs = 0; good epochs = 1
# [4] running loss: 48.302090; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# [5] running loss: 28.121293; bad epochs = 0; good epochs = 0
# Finished Training.

# %%
visual_test_numpy_equivalence_relu()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 145.930036; bad epochs = 0; good epochs = 0
# [2] running loss: 87.625025; bad epochs = 1; good epochs = 0
# [3] running loss: 82.271796; bad epochs = 0; good epochs = 1
# [4] running loss: 74.901108; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# [5] running loss: 60.492530; bad epochs = 0; good epochs = 0
# Finished Training.

# %%
visual_test_numpy_equivalence_tanh()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 56.688132; bad epochs = 0; good epochs = 0
# [2] running loss: 90.559049; bad epochs = 1; good epochs = 0
# [3] running loss: 89.645156; bad epochs = 2; good epochs = 0
# [4] running loss: 75.412955; bad epochs = 0; good epochs = 1
# [5] running loss: 48.767380; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# Finished Training.
