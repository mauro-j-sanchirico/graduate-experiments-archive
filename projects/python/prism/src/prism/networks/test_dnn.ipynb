# %% [markdown]
# # DNN Visual Tests

# %%
# %load_ext autoreload
# %autoreload 2

from prism.networks.dnn import visual_test_fit_infer
from prism.networks.dnn import visual_test_save_load
from prism.networks.dnn import visual_test_numpy_equivalence_relu
from prism.networks.dnn import visual_test_numpy_equivalence_tanh
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
visual_test_fit_infer()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 132.235073; bad epochs = 0; good epochs = 0
# [2] running loss: 96.784423; bad epochs = 1; good epochs = 0
# [3] running loss: 75.047037; bad epochs = 0; good epochs = 1
# [4] running loss: 69.549931; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# [5] running loss: 60.254202; bad epochs = 0; good epochs = 0
# Finished Training.

# %%
visual_test_save_load()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 179.694389; bad epochs = 0; good epochs = 0
# [2] running loss: 73.405872; bad epochs = 1; good epochs = 0
# [3] running loss: 51.123777; bad epochs = 0; good epochs = 1
# [4] running loss: 34.983828; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# [5] running loss: 27.935019; bad epochs = 0; good epochs = 0
# Finished Training.

# %%
visual_test_numpy_equivalence_relu()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 140.065610; bad epochs = 0; good epochs = 0
# [2] running loss: 94.047260; bad epochs = 1; good epochs = 0
# [3] running loss: 53.345879; bad epochs = 0; good epochs = 1
# [4] running loss: 28.910993; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# [5] running loss: 19.209392; bad epochs = 0; good epochs = 0
# Finished Training.

# %%
visual_test_numpy_equivalence_tanh()
# Out:
# Fitting using device: cuda:0
# [1] running loss: 59.535669; bad epochs = 0; good epochs = 0
# [2] running loss: 96.999113; bad epochs = 1; good epochs = 0
# [3] running loss: 92.222035; bad epochs = 2; good epochs = 0
# [4] running loss: 66.652401; bad epochs = 0; good epochs = 1
# [5] running loss: 42.528223; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# Finished Training.
