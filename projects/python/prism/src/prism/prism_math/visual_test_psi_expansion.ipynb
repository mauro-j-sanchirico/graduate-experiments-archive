# %%
# %load_ext autoreload
# %autoreload 2

from prism.prism_math.psi_expansion import visual_test_psi_coefs

# %%
visual_test_psi_coefs()
# Out:
# Loading the alpha coefs...
# Getting the multinomial coefficient tables...
# Instantiating the networks...
# Getting a stimulus signal...
# Training the neural networks to fit some arbitrary output...
# Fitting using device: cuda:0
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\torch\nn\modules\loss.py:446: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# [1] running loss: 79.605224; bad epochs = 0; good epochs = 0
# [2] running loss: 59.694124; bad epochs = 1; good epochs = 0
# [3] running loss: 53.525919; bad epochs = 0; good epochs = 1
# [4] running loss: 47.004055; bad epochs = 0; good epochs = 2
# Increasing learning rate by x1.01...
# [5] running loss: 48.763422; bad epochs = 0; good epochs = 0
# Finished Training.
# Fitting using device: cuda:0
# ...
