# %% [markdown]
# # Visually Test Activation Coefficients

# %%
# %load_ext autoreload
# %autoreload 2

from prism.prism_math.activation_coefs import \
    visual_test_alpha_coefs_tanh, \
    visual_test_taylor_coefs_tanh, \
    visual_test_alpha_coefs_sech, \
    visual_test_alpha_coefs_sech2, \
    visual_test_alpha_coefs_relu

# %%
# Rectified Linear Unit
visual_test_alpha_coefs_relu()

# Hyperbolic Tangent
visual_test_alpha_coefs_tanh()

# Hyperbolic Tangent - Taylor
visual_test_taylor_coefs_tanh()

# Hyperbolic Secant
visual_test_alpha_coefs_sech()

# Hyperbolic Secant
visual_test_alpha_coefs_sech2()
