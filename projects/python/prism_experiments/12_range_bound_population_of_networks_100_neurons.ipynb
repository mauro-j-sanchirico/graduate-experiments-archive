# %% [markdown]
# # Experiment 12: Range Bound Population of DNNs with 25 Neurons Per Layer
#
# In this experiment we perform range bounding on a population of DNNs and collect statistics over the population including:
#
# * min / max range via numerical
# * min / max range via Taylor
# * min / max range via AMIE
# * Overestimation of Taylor vs. numerical
# * Overestimation of AMIE vs. numerical
# * Runtime to generate AMIE coefs
# * Runtime to range bound via AMIE
# * N hidden nodes per layer (all layers the same)
# * N Layers
#
# All statistics are stored in a dataframe and plotted.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import time

from experiment_utils_range_bounding import (
    get_population_of_dnns,
    range_bound_dnn_numerical,
    range_bound_dnn_taylor_model
)

from prism.analysis import boxplot_utils

from verified_computing import taylorfactory

# %% [markdown]
# ## Get a Population of Networks

# %%
n_per_group = 3

hidden_nodes_list = [
    (50,) * 2,
    (50,) * 3,
    (50,) * 4,
    (50,) * 5,
    (50,) * 6,
]

inputs_list = [3,]

activation_list = ['tanh', ] # 'tanh', 'relu'

# %%
population, metadata_df = get_population_of_dnns(
    n_per_group,
    hidden_nodes_list,
    inputs_list,
    activation_list,
    lr=0.01,
    momentum=0.1,
    rho=0.9,
    eps=1e-06,
    betas=(0.9, 0.99),
    use_gpu=True,
    optimizer_method='adam',
    weight_decay=0.01,
)

# %%
print('Generated {} networks:'.format(len(metadata_df)))
metadata_df.head()
# Out:
# Generated 15 networks:
#   activation  n_inputs  n_hidden_nodes_per_layer  n_layers
# 0       tanh         3                        50         3
# 1       tanh         3                        50         3
# 2       tanh         3                        50         3
# 3       tanh         3                        50         4
# 4       tanh         3                        50         4

# %% [markdown]
# ## Loop through the population and perform range bounding
#
# For each network in the population, range bounding is performed over increasingly large interval sizes.  The range bounding procedure first involves performing a numerical heuristic analysis to obtain appropriate suggested v_max values.  Then the network is bounded via both Taylor and AMIE polynomials.  The overestimation of the Taylor and AMIE polynomials range bounding procuedures vs. the numerical procedure is tabulated.  Runtime to build the AMIE polynomials and to perform the range bounding is recorded sepparately.

# %%
# Prepare a results dataframe
results_columns = [
    'activation',
    'n_inputs',
    'n_hidden_nodes_per_layer',
    'n_layers',
    'min_range_numerical',
    'max_range_numerical',
    'min_range_taylor',
    'max_range_taylor',
    'min_range_amie',
    'max_range_amie',
    'overestimation_taylor',
    'overestimation_amie',
    'runtime_to_generate_amie_coefs',
    'runtime_to_range_bound_via_amie',
    'domain_interval_width'
]

# Prepare a list of interval widths to analyze
interval_widths = [
    0.01,
    0.1,
    0.5,
    1,
    1.5,
    2,
]

n_points_numerical = 100

# Taylor model parameters
big_m = 25
dps = 260
tol_finalization_step = 1e-8
n_subdomains = 100
v_mult = 100

# %%
results_list = []

for idx, network in enumerate(population):

    print('\nPerforming range analysis on network {}\n'.format(idx))
 
    for interval_width in interval_widths:

        print('  * Analyzing domain width {}'.format(interval_width))

        # 1) Obtain a domain interval to analyze
        x_min = - interval_width / 2.0
        x_max = interval_width / 2.0

        # 2) Perform initial range bounding numerically
        y_min_numer, y_max_numer, v_min_list, v_max_list = \
            range_bound_dnn_numerical(
                network, x_min, x_max, n_points_numerical)

        # 3) Obtain a guess for v_max using the numerical results
        v_min = np.min(v_min_list)
        v_max = np.max(v_max_list)
        v_max = v_mult*np.max([np.abs(v_min), np.abs(v_max)])

        print('  * v_max suggestion: {}'.format(v_max))

        # 4) Obtain a Taylor model for the given v_max
        activation_type = metadata_df.loc[idx, 'activation']

        if activation_type == 'relu':
            t0 = time.time()
            t_amie = taylorfactory.get_taylor_model(
                function_type='relu',
                big_m=big_m,
                v_max=v_max,
                dps=dps,
                silent=True,
                n_brute_points=250,
                tol_final=tol_finalization_step
            )
            t1 = time.time()
            time_to_generate_amie_polynomials = t1 - t0

            print('  * AMIE ReLU model error: {}', t_amie.error.tostr())

            # Cannot construct a conventional Taylor model for ReLU
            t_taylor = None

        elif activation_type == 'tanh':
            t0 = time.time()
            t_amie = taylorfactory.get_taylor_model(
                function_type='tanh',
                big_m=big_m,
                v_max=v_max,
                dps=dps,
                silent=True,
                n_brute_points=100,
                tol_final=tol_finalization_step
            )
            t1 = time.time()
            time_to_generate_amie_polynomials = t1 - t0

            print('  * AMIE Tanh model error: {}', t_amie.error.tostr())

            #t_taylor = taylorfactory.get_taylor_model(
            #    function_type='tanh_taylor',
            #    big_m=big_m,
            #    v_max=v_max,
            #    dps=dps,
            #    silent=True,
            #    n_brute_points=100,
            #    tol_final=tol_finalization_step
            #)

            #print('  * Taylor Tanh model error: {}', t_taylor.error.tostr())

        # 5) Use the given Taylor models to perform range bounding
        #y_min_taylor, y_max_taylor, v_list_taylor = range_bound_dnn_taylor_model(
        #    network, t_taylor, x_min, x_max, n_subdomains
        #)
        y_min_taylor = np.inf
        y_max_taylor = np.inf 

        t0 = time.time()
        y_min_amie, y_max_amie, v_list_amie = range_bound_dnn_taylor_model(
            network, t_amie, x_min, x_max, n_subdomains
        )
        t1 = time.time()
        time_to_range_bound_amie = t1 - t0

        # 6) Compare range bounds with numerical bounds
        width_numer = y_max_numer - y_min_numer
        width_taylor = y_max_taylor - y_min_taylor
        width_amie = y_max_amie - y_min_amie

        overestimate_taylor = width_taylor - width_numer
        overestimate_amie = width_amie - width_numer

        # 7) Store metrics
        results_row = [
            activation_type,
            metadata_df.loc[idx, 'n_inputs'],
            metadata_df.loc[idx, 'n_hidden_nodes_per_layer'],
            metadata_df.loc[idx, 'n_layers'],
            y_min_numer,
            y_max_numer,
            y_min_taylor,
            y_max_taylor,
            y_min_amie,
            y_max_amie,
            overestimate_taylor,
            overestimate_amie,
            time_to_generate_amie_polynomials,
            time_to_range_bound_amie,
            interval_width
        ]

        results_list.append(results_row)

results_df = pd.DataFrame(results_list, columns=results_columns)
# Out:
# Performing range analysis on network 0
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.32127546853392
#   * AMIE Tanh model error: {} [[-0.57498025], [0.57498025]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 61.376963234927
#   * AMIE Tanh model error: {} [[-0.59458333], [0.59458333]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 79.28926919724483
#   * AMIE Tanh model error: {} [[-0.66211681], [0.66211681]]
#   * Analyzing domain width 1
#   * v_max suggestion: 105.02579936919065
#   * AMIE Tanh model error: {} [[-0.72559687], [0.72559687]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 121.69844269010903
#   * AMIE Tanh model error: {} [[-0.75462917], [0.75462917]]
#   * Analyzing domain width 2
#   * v_max suggestion: 158.11331004276852
#   * AMIE Tanh model error: {} [[-0.7996151], [0.7996151]]
#
# Performing range analysis on network 1
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 62.11610620415182
#   * AMIE Tanh model error: {} [[-0.59794853], [0.59794853]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 63.80799430110753
#   * AMIE Tanh model error: {} [[-0.60542927], [0.60542927]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 77.92800340353044
#   * AMIE Tanh model error: {} [[-0.65784484], [0.65784484]]
#   * Analyzing domain width 1
#   * v_max suggestion: 107.31263620521452
#   * AMIE Tanh model error: {} [[-0.73001733], [0.73001733]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 128.0278567428586
#   * AMIE Tanh model error: {} [[-0.76398211], [0.76398211]]
#   * Analyzing domain width 2
#   * v_max suggestion: 163.3440435817312
#   * AMIE Tanh model error: {} [[-0.80465821], [0.80465821]]
#
# Performing range analysis on network 2
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.75259389207197
#   * AMIE Tanh model error: {} [[-0.57716163], [0.57716163]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 60.287878982719135
#   * AMIE Tanh model error: {} [[-0.58951266], [0.58951266]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 79.88834965101246
#   * AMIE Tanh model error: {} [[-0.66396038], [0.66396038]]
#   * Analyzing domain width 1
#   * v_max suggestion: 110.7476447539288
#   * AMIE Tanh model error: {} [[-0.73637336], [0.73637336]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 134.07256702959418
#   * AMIE Tanh model error: {} [[-0.77221843], [0.77221843]]
#   * Analyzing domain width 2
#   * v_max suggestion: 168.65778815794755
#   * AMIE Tanh model error: {} [[-0.80950643], [0.80950643]]
#
# Performing range analysis on network 3
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 56.55491520301864
#   * AMIE Tanh model error: {} [[-0.57104414], [0.57104414]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 57.83679244458626
#   * AMIE Tanh model error: {} [[-0.57758465], [0.57758465]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 78.9823682159975
#   * AMIE Tanh model error: {} [[-0.66116383], [0.66116383]]
#   * Analyzing domain width 1
#   * v_max suggestion: 102.48542324240147
#   * AMIE Tanh model error: {} [[-0.72049724], [0.72049724]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 130.94697224536915
#   * AMIE Tanh model error: {} [[-0.76803931], [0.76803931]]
#   * Analyzing domain width 2
#   * v_max suggestion: 155.94162525113867
#   * AMIE Tanh model error: {} [[-0.79743681], [0.79743681]]
#
# Performing range analysis on network 4
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.847488829036294
#   * AMIE Tanh model error: {} [[-0.57763833], [0.57763833]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 60.56936464098824
#   * AMIE Tanh model error: {} [[-0.59083629], [0.59083629]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 76.23767893824504
#   * AMIE Tanh model error: {} [[-0.65237383], [0.65237383]]
#   * Analyzing domain width 1
#   * v_max suggestion: 100.94690097906167
#   * AMIE Tanh model error: {} [[-0.7173069], [0.7173069]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 132.32086970685637
#   * AMIE Tanh model error: {} [[-0.76989673], [0.76989673]]
#   * Analyzing domain width 2
#   * v_max suggestion: 164.0654872479328
#   * AMIE Tanh model error: {} [[-0.80533218], [0.80533218]]
#
# Performing range analysis on network 5
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.638336459544725
#   * AMIE Tanh model error: {} [[-0.57658612], [0.57658612]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 60.83190642456415
#   * AMIE Tanh model error: {} [[-0.59206258], [0.59206258]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 80.22661001384535
#   * AMIE Tanh model error: {} [[-0.66499169], [0.66499169]]
#   * Analyzing domain width 1
#   * v_max suggestion: 104.87055367171175
#   * AMIE Tanh model error: {} [[-0.72529105], [0.72529105]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 137.35552459997663
#   * AMIE Tanh model error: {} [[-0.77643499], [0.77643499]]
#   * Analyzing domain width 2
#   * v_max suggestion: 158.2934540255443
#   * AMIE Tanh model error: {} [[-0.79979351], [0.79979351]]
#
# Performing range analysis on network 6
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.87087677714295
#   * AMIE Tanh model error: {} [[-0.57775564], [0.57775564]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 61.84370810404541
#   * AMIE Tanh model error: {} [[-0.59671537], [0.59671537]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 83.13507909746257
#   * AMIE Tanh model error: {} [[-0.67358341], [0.67358341]]
#   * Analyzing domain width 1
#   * v_max suggestion: 105.16163346546061
#   * AMIE Tanh model error: {} [[-0.72586385], [0.72586385]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 130.4509999014402
#   * AMIE Tanh model error: {} [[-0.76736072], [0.76736072]]
#   * Analyzing domain width 2
#   * v_max suggestion: 160.8526915875378
#   * AMIE Tanh model error: {} [[-0.80229113], [0.80229113]]
#
# Performing range analysis on network 7
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.02087233409583
#   * AMIE Tanh model error: {} [[-0.57344663], [0.57344663]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 60.50866485155715
#   * AMIE Tanh model error: {} [[-0.59055164], [0.59055164]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 79.37705930709014
#   * AMIE Tanh model error: {} [[-0.66238834], [0.66238834]]
#   * Analyzing domain width 1
#   * v_max suggestion: 104.07397428820234
#   * AMIE Tanh model error: {} [[-0.72371007], [0.72371007]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 126.72968793435793
#   * AMIE Tanh model error: {} [[-0.76212761], [0.76212761]]
#   * Analyzing domain width 2
#   * v_max suggestion: 187.3266111710309
#   * AMIE Tanh model error: {} [[-0.82464858], [0.82464858]]
#
# Performing range analysis on network 8
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 56.256847801756436
#   * AMIE Tanh model error: {} [[-0.569492], [0.569492]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 59.19245716709194
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\scipy\optimize\_hessian_update_strategy.py:186: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   'approximations.', UserWarning)
#   * AMIE Tanh model error: {} [[-0.58427261], [0.58427261]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 85.74826405746889
#   * AMIE Tanh model error: {} [[-0.68090486], [0.68090486]]
#   * Analyzing domain width 1
#   * v_max suggestion: 111.9643745010452
#   * AMIE Tanh model error: {} [[-0.73854733], [0.73854733]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 136.6097483199539
#   * AMIE Tanh model error: {} [[-0.77549212], [0.77549212]]
#   * Analyzing domain width 2
#   * v_max suggestion: 167.85740004165004
#   * AMIE Tanh model error: {} [[-0.80879298], [0.80879298]]
#
# Performing range analysis on network 9
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 71.15473255688217
#   * AMIE Tanh model error: {} [[-0.63471177], [0.63471177]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 71.75493667349868
#   * AMIE Tanh model error: {} [[-0.63689833], [0.63689833]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 86.12847912168967
#   * AMIE Tanh model error: {} [[-0.68194049], [0.68194049]]
#   * Analyzing domain width 1
#   * v_max suggestion: 109.85439391990911
#   * AMIE Tanh model error: {} [[-0.73475209], [0.73475209]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 139.55718972832113
#   * AMIE Tanh model error: {} [[-0.77916881], [0.77916881]]
#   * Analyzing domain width 2
#   * v_max suggestion: 179.1000292992489
#   * AMIE Tanh model error: {} [[-0.81831061], [0.81831061]]
#
# Performing range analysis on network 10
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.632851209544334
#   * AMIE Tanh model error: {} [[-0.57655845], [0.57655845]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 62.032373443787655
#   * AMIE Tanh model error: {} [[-0.59757033], [0.59757033]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 83.4104744460811
#   * AMIE Tanh model error: {} [[-0.6743722], [0.6743722]]
#   * Analyzing domain width 1
#   * v_max suggestion: 102.23219515600445
#   * AMIE Tanh model error: {} [[-0.71997754], [0.71997754]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 133.52480761830222
#   * AMIE Tanh model error: {} [[-0.77149793], [0.77149793]]
#   * Analyzing domain width 2
#   * v_max suggestion: 158.02252563939737
#   * AMIE Tanh model error: {} [[-0.79952507], [0.79952507]]
#
# Performing range analysis on network 11
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 58.24851253507946
#   * AMIE Tanh model error: {} [[-0.57964017], [0.57964017]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 61.89949302182285
#   * AMIE Tanh model error: {} [[-0.59696858], [0.59696858]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 78.87268216842844
#   * AMIE Tanh model error: {} [[-0.66082182], [0.66082182]]
#   * Analyzing domain width 1
#   * v_max suggestion: 108.88009932089882
#   * AMIE Tanh model error: {} [[-0.73295873], [0.73295873]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 130.79883112702205
#   * AMIE Tanh model error: {} [[-0.76783708], [0.76783708]]
#   * Analyzing domain width 2
#   * v_max suggestion: 149.43771135513774
#   * AMIE Tanh model error: {} [[-0.79059245], [0.79059245]]
#
# Performing range analysis on network 12
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.69400322642316
#   * AMIE Tanh model error: {} [[-0.57686672], [0.57686672]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 60.777064710319685
#   * AMIE Tanh model error: {} [[-0.59180708], [0.59180708]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 80.55437498238359
#   * AMIE Tanh model error: {} [[-0.66598447], [0.66598447]]
#   * Analyzing domain width 1
#   * v_max suggestion: 97.20776497460592
#   * AMIE Tanh model error: {} [[-0.7092115], [0.7092115]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 151.41435047183478
#   * AMIE Tanh model error: {} [[-0.79272538], [0.79272538]]
#   * Analyzing domain width 2
#   * v_max suggestion: 159.46195436701922
#   * AMIE Tanh model error: {} [[-0.80094236], [0.80094236]]
#
# Performing range analysis on network 13
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 57.04019601878553
#   * AMIE Tanh model error: {} [[-0.57354564], [0.57354564]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 59.92457409172647
#   * AMIE Tanh model error: {} [[-0.58779058], [0.58779058]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 76.0354382307924
#   * AMIE Tanh model error: {} [[-0.65170648], [0.65170648]]
#   * Analyzing domain width 1
#   * v_max suggestion: 92.05204915382559
#   * AMIE Tanh model error: {} [[-0.69718063], [0.69718063]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 117.97694615382714
#   * AMIE Tanh model error: {} [[-0.74874145], [0.74874145]]
#   * Analyzing domain width 2
#   * v_max suggestion: 129.7798306961345
#   * AMIE Tanh model error: {} [[-0.76643551], [0.76643551]]
#
# Performing range analysis on network 14
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 56.84277053490604
#   * AMIE Tanh model error: {} [[-0.57253175], [0.57253175]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 60.1176936302096
#   * AMIE Tanh model error: {} [[-0.58870791], [0.58870791]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 82.03767911595725
#   * AMIE Tanh model error: {} [[-0.67039848], [0.67039848]]
#   * Analyzing domain width 1
#   * v_max suggestion: 111.23657182234359
#   * AMIE Tanh model error: {} [[-0.73725167], [0.73725167]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 117.64855940256558
#   * AMIE Tanh model error: {} [[-0.74820706], [0.74820706]]
#   * Analyzing domain width 2
#   * v_max suggestion: 165.6003921017573
#   * AMIE Tanh model error: {} [[-0.80674938], [0.80674938]]

# %%
# Copy the original dataframe
results_df_orign = results_df.copy(deep=True)

results_df.head(200)
# Out:
#    activation  n_inputs  n_hidden_nodes_per_layer  n_layers  \
# 0        tanh         3                        50         3
# 1        tanh         3                        50         3
# 2        tanh         3                        50         3
# 3        tanh         3                        50         3
# 4        tanh         3                        50         3
# ..        ...       ...                       ...       ...
# 85       tanh         3                        50         7
# 86       tanh         3                        50         7
# 87       tanh         3                        50         7
# 88       tanh         3                        50         7
# 89       tanh         3                        50         7
#
#     min_range_numerical  max_range_numerical  min_range_taylor  \
# 0             -0.067758            -0.067011               inf
# 1             -0.070732            -0.063588               inf
# 2             -0.087774            -0.049966               inf
# 3             -0.109783            -0.032236               inf
# 4             -0.128863            -0.022829               inf
# ..                  ...                  ...               ...
# 85             0.104684             0.105979               inf
# 86             0.102110             0.108670               inf
# 87             0.098623             0.111927               inf
# 88             0.094857             0.115214               inf
# 89             0.091719             0.118133               inf
#
#     max_range_taylor         min_range_amie        max_range_amie  \
# 0                inf   [-4.005622391115695]   [3.908539186734575]
# 1                inf  [-4.0508057382851765]   [3.954232664438672]
# 2                inf   [-4.150222853528673]   [4.055203858472727]
# 3                inf  [-4.1674746670991505]  [4.0736738220498525]
# 4                inf    [-4.16992773703211]   [4.076620854818893]
# ..               ...                    ...                   ...
# 85               inf   [-4.928449483857162]   [5.088268548453198]
# 86               inf    [-4.32865358327229]   [4.488524763586894]
# 87               inf   [-3.850451339648238]   [4.008410280271269]
# 88               inf  [-3.7831851499270823]  [3.9407428703428744]
# 89               inf  [-3.4827696222959235]   [3.638023999397521]
#
#     overestimation_taylor   overestimation_amie  \
# 0                     NaN    [7.91341499569794]
# 1                     NaN   [7.997894015849406]
# 2                     NaN   [8.167619257460295]
# 3                     NaN    [8.16360089491597]
# 4                     NaN   [8.140514840662627]
# ..                    ...                   ...
# 85                    NaN  [10.015422872724006]
# 86                    NaN   [8.810618518290987]
# 87                    NaN   [7.845557156876701]
# 88                    NaN   [7.703570815670805]
# 89                    NaN   [7.094379136899923]
#
#     runtime_to_generate_amie_coefs  runtime_to_range_bound_via_amie  \
# 0                        30.526022                         8.855609
# 1                        34.146789                         8.995246
# 2                        41.879661                         8.939913
# 3                        49.588026                         9.019909
# 4                        50.269252                         8.831808
# ..                             ...                              ...
# 85                       34.281686                        26.418979
# 86                       41.824894                        26.572731
# 87                       51.525879                        26.303398
# 88                       51.998068                        26.537608
# 89                       49.616069                        26.335704
#
#     domain_interval_width
# 0                    0.01
# 1                    0.10
# 2                    0.50
# 3                    1.00
# 4                    1.50
# ..                    ...
# 85                   0.10
# 86                   0.50
# 87                   1.00
# 88                   1.50
# 89                   2.00
#
# [90 rows x 15 columns]

# %%
# Remove outliers due to Taylor divergence
inf_threshold = 1000
results_df.loc[results_df['overestimation_taylor'] > inf_threshold, 'overestimation_taylor'] = np.inf

results_df.loc[results_df['overestimation_amie'] > inf_threshold, 'overestimation_amie'] = np.inf

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_interval_width_amie.png',
    results_df,
    xcol='domain_interval_width', ycol='overestimation_amie',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='Domain Interval Width')

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_n_layers_amie.png',
    results_df,
    xcol='n_layers', ycol='overestimation_amie',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='N. Layers')

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_interval_width_taylor.png',
    results_df,
    xcol='domain_interval_width', ycol='overestimation_taylor',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='Domain Interval Width')

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_n_layers_taylor.png',
    results_df,
    xcol='n_layers', ycol='overestimation_taylor',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='N. Layers')

# %%
boxplot_utils.make_boxplot(
    'plots/runtime_range_bound_wrt_n_layers.png',
    results_df,
    xcol='n_layers', ycol='runtime_to_range_bound_via_amie',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='N. Layers')

# %%
boxplot_utils.make_boxplot(
    'plots/runtime_generate_coefs_wrt_interval_width.png',
    results_df,
    xcol='domain_interval_width', ycol='runtime_to_generate_amie_coefs',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='Domain Interval Width')
