# %% [markdown]
# # Experiment 11: Range Bound Population of DNNs with 25 Neurons Per Layer
#
# In this experiment we perform range bounding on a population of DNNs and collect statistics over the population including:
#
# * min / max range via numerical
# * min / max range via Taylor
# * min / max range via AMIE
# * Overestimation of Taylor vs. numerical
# * Overestimation of AMIE vs. numerical
# * Runtime to generate AMIE coefs
# * Runtime to range bound via AMIE
# * N hidden nodes per layer (all layers the same)
# * N Layers
#
# All statistics are stored in a dataframe and plotted.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import time

from experiment_utils_range_bounding import (
    get_population_of_dnns,
    range_bound_dnn_numerical,
    range_bound_dnn_taylor_model
)

from prism.analysis import boxplot_utils

from verified_computing import taylorfactory

# %% [markdown]
# ## Get a Population of Networks

# %%
n_per_group = 3

hidden_nodes_list = [
    (25,) * 2,
    (25,) * 3,
    (25,) * 4,
    (25,) * 5,
    (25,) * 6,
]

inputs_list = [3,]

activation_list = ['tanh', ] # 'tanh', 'relu'

# %%
population, metadata_df = get_population_of_dnns(
    n_per_group,
    hidden_nodes_list,
    inputs_list,
    activation_list,
    lr=0.01,
    momentum=0.1,
    rho=0.9,
    eps=1e-06,
    betas=(0.9, 0.99),
    use_gpu=True,
    optimizer_method='adam',
    weight_decay=0.01,
)

# %%
print('Generated {} networks:'.format(len(metadata_df)))
metadata_df.head()
# Out:
# Generated 15 networks:
#   activation  n_inputs  n_hidden_nodes_per_layer  n_layers
# 0       tanh         3                        25         3
# 1       tanh         3                        25         3
# 2       tanh         3                        25         3
# 3       tanh         3                        25         4
# 4       tanh         3                        25         4

# %% [markdown]
# ## Loop through the population and perform range bounding
#
# For each network in the population, range bounding is performed over increasingly large interval sizes.  The range bounding procedure first involves performing a numerical heuristic analysis to obtain appropriate suggested v_max values.  Then the network is bounded via both Taylor and AMIE polynomials.  The overestimation of the Taylor and AMIE polynomials range bounding procuedures vs. the numerical procedure is tabulated.  Runtime to build the AMIE polynomials and to perform the range bounding is recorded sepparately.

# %%
# Prepare a results dataframe
results_columns = [
    'activation',
    'n_inputs',
    'n_hidden_nodes_per_layer',
    'n_layers',
    'min_range_numerical',
    'max_range_numerical',
    'min_range_taylor',
    'max_range_taylor',
    'min_range_amie',
    'max_range_amie',
    'overestimation_taylor',
    'overestimation_amie',
    'runtime_to_generate_amie_coefs',
    'runtime_to_range_bound_via_amie',
    'domain_interval_width'
]

# Prepare a list of interval widths to analyze
interval_widths = [
    0.01,
    0.1,
    0.5,
    1,
    1.5,
    2,
]

n_points_numerical = 100

# Taylor model parameters
big_m = 12
dps = 130
tol_finalization_step = 1e-6
n_subdomains = 100
v_mult = 8

# %%
results_list = []

for idx, network in enumerate(population):

    print('\nPerforming range analysis on network {}\n'.format(idx))
 
    for interval_width in interval_widths:

        print('  * Analyzing domain width {}'.format(interval_width))

        # 1) Obtain a domain interval to analyze
        x_min = - interval_width / 2.0
        x_max = interval_width / 2.0

        # 2) Perform initial range bounding numerically
        y_min_numer, y_max_numer, v_min_list, v_max_list = \
            range_bound_dnn_numerical(
                network, x_min, x_max, n_points_numerical)

        # 3) Obtain a guess for v_max using the numerical results
        v_min = np.min(v_min_list)
        v_max = np.max(v_max_list)
        v_max = v_mult*np.max([np.abs(v_min), np.abs(v_max)])

        print('  * v_max suggestion: {}'.format(v_max))

        # 4) Obtain a Taylor model for the given v_max
        activation_type = metadata_df.loc[idx, 'activation']

        if activation_type == 'relu':
            t0 = time.time()
            t_amie = taylorfactory.get_taylor_model(
                function_type='relu',
                big_m=big_m,
                v_max=v_max,
                dps=dps,
                silent=True,
                n_brute_points=250,
                tol_final=tol_finalization_step
            )
            t1 = time.time()
            time_to_generate_amie_polynomials = t1 - t0

            print('  * AMIE ReLU model error: {}', t_amie.error.tostr())

            # Cannot construct a conventional Taylor model for ReLU
            t_taylor = None

        elif activation_type == 'tanh':
            t0 = time.time()
            t_amie = taylorfactory.get_taylor_model(
                function_type='tanh',
                big_m=big_m,
                v_max=v_max,
                dps=dps,
                silent=True,
                n_brute_points=100,
                tol_final=tol_finalization_step
            )
            t1 = time.time()
            time_to_generate_amie_polynomials = t1 - t0

            print('  * AMIE Tanh model error: {}', t_amie.error.tostr())

            t_taylor = taylorfactory.get_taylor_model(
                function_type='tanh_taylor',
                big_m=big_m,
                v_max=v_max,
                dps=dps,
                silent=True,
                n_brute_points=100,
                tol_final=tol_finalization_step
            )

            print('  * Taylor Tanh model error: {}', t_taylor.error.tostr())

        # 5) Use the given Taylor models to perform range bounding
        y_min_taylor, y_max_taylor, v_list_taylor = range_bound_dnn_taylor_model(
            network, t_taylor, x_min, x_max, n_subdomains
        )

        t0 = time.time()
        y_min_amie, y_max_amie, v_list_amie = range_bound_dnn_taylor_model(
            network, t_amie, x_min, x_max, n_subdomains
        )
        t1 = time.time()
        time_to_range_bound_amie = t1 - t0

        # 6) Compare range bounds with numerical bounds
        width_numer = y_max_numer - y_min_numer
        width_taylor = y_max_taylor - y_min_taylor
        width_amie = y_max_amie - y_min_amie

        overestimate_taylor = width_taylor - width_numer
        overestimate_amie = width_amie - width_numer

        # 7) Store metrics
        results_row = [
            activation_type,
            metadata_df.loc[idx, 'n_inputs'],
            metadata_df.loc[idx, 'n_hidden_nodes_per_layer'],
            metadata_df.loc[idx, 'n_layers'],
            y_min_numer,
            y_max_numer,
            y_min_taylor,
            y_max_taylor,
            y_min_amie,
            y_max_amie,
            overestimate_taylor,
            overestimate_amie,
            time_to_generate_amie_polynomials,
            time_to_range_bound_amie,
            interval_width
        ]

        results_list.append(results_row)

results_df = pd.DataFrame(results_list, columns=results_columns)
# Out:
# Performing range analysis on network 0
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.626798758074947
#   * AMIE Tanh model error: {} [[-0.02964246], [0.02964246]]
#   * Taylor Tanh model error: {} [[-7.05067777e+10], [7.05067777e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.82763560998426
#   * AMIE Tanh model error: {} [[-0.03447643], [0.03447643]]
#   * Taylor Tanh model error: {} [[-1.8894794e+11], [1.8894794e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.144211565455743
#   * AMIE Tanh model error: {} [[-0.07231202], [0.07231202]]
#   * Taylor Tanh model error: {} [[-5.02780652e+13], [5.02780652e+13]]
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:752: RuntimeWarning: overflow encountered in power
#   interval_result.x1 = interval.x1 ** integer_exponent_odd
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:753: RuntimeWarning: overflow encountered in power
#   interval_result.x2 = interval.x2 ** integer_exponent_odd
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:704: RuntimeWarning: overflow encountered in power
#   interval_result.x1 = interval.x2 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:705: RuntimeWarning: overflow encountered in power
#   interval_result.x2 = interval.x1 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:640: RuntimeWarning: invalid value encountered in multiply
#   x1_result_candidate1 = interval_a.x1 * interval_b.x1
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:641: RuntimeWarning: invalid value encountered in multiply
#   x1_result_candidate2 = interval_a.x1 * interval_b.x2
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:642: RuntimeWarning: invalid value encountered in multiply
#   x1_result_candidate3 = interval_a.x2 * interval_b.x1
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:643: RuntimeWarning: invalid value encountered in multiply
#   x1_result_candidate4 = interval_a.x2 * interval_b.x2
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:730: RuntimeWarning: overflow encountered in power
#   interval_result.x2 = interval.x2 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:729: RuntimeWarning: overflow encountered in power
#   interval_result.x1 = interval.x1 ** integer_exponent_even
#   * Analyzing domain width 1
#   * v_max suggestion: 8.080712061851496
#   * AMIE Tanh model error: {} [[-0.13725462], [0.13725462]]
#   * Taylor Tanh model error: {} [[-2.81440326e+16], [2.81440326e+16]]
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:709: RuntimeWarning: overflow encountered in power
#   interval_result.x2 = interval.x1 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:725: RuntimeWarning: overflow encountered in power
#   interval_result.x2 = interval.x2 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:714: RuntimeWarning: overflow encountered in power
#   interval.x1 ** integer_exponent_even,
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:715: RuntimeWarning: overflow encountered in power
#   interval.x2 ** integer_exponent_even,
#   * Analyzing domain width 1.5
#   * v_max suggestion: 9.481259108456985
#   * AMIE Tanh model error: {} [[-0.18447701], [0.18447701]]
#   * Taylor Tanh model error: {} [[-1.12282359e+18], [1.12282359e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 10.99465416698009
#   * AMIE Tanh model error: {} [[-0.23269183], [0.23269183]]
#   * Taylor Tanh model error: {} [[-3.4084251e+19], [3.4084251e+19]]
#
# Performing range analysis on network 1
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.513415569731181
#   * AMIE Tanh model error: {} [[-0.02705452], [0.02705452]]
#   * Taylor Tanh model error: {} [[-3.96389223e+10], [3.96389223e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.696985689445435
#   * AMIE Tanh model error: {} [[-0.03129638], [0.03129638]]
#   * Taylor Tanh model error: {} [[-9.99891068e+10], [9.99891068e+10]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.468907599722408
#   * AMIE Tanh model error: {} [[-0.08277736], [0.08277736]]
#   * Taylor Tanh model error: {} [[-1.65342331e+14], [1.65342331e+14]]
#   * Analyzing domain width 1
#   * v_max suggestion: 7.436539894452585
#   * AMIE Tanh model error: {} [[-0.11522945], [0.11522945]]
#   * Taylor Tanh model error: {} [[-4.13739457e+15], [4.13739457e+15]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 9.599529053399479
#   * AMIE Tanh model error: {} [[-0.18836986], [0.18836986]]
#   * Taylor Tanh model error: {} [[-1.49425844e+18], [1.49425844e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 11.2017309858176
#   * AMIE Tanh model error: {} [[-0.23899489], [0.23899489]]
#   * Taylor Tanh model error: {} [[-5.23906874e+19], [5.23906874e+19]]
#
# Performing range analysis on network 2
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.501692544721606
#   * AMIE Tanh model error: {} [[-0.026793], [0.026793]]
#   * Taylor Tanh model error: {} [[-3.73163271e+10], [3.73163271e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.731472191058352
#   * AMIE Tanh model error: {} [[-0.03212317], [0.03212317]]
#   * Taylor Tanh model error: {} [[-1.1848406e+11], [1.1848406e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 5.869325342203121
#   * AMIE Tanh model error: {} [[-0.06371991], [0.06371991]]
#   * Taylor Tanh model error: {} [[-1.74436922e+13], [1.74436922e+13]]
#   * Analyzing domain width 1
#   * v_max suggestion: 9.009840704296401
#   * AMIE Tanh model error: {} [[-0.16878595], [0.16878595]]
#   * Taylor Tanh model error: {} [[-3.46451699e+17], [3.46451699e+17]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 11.480020833530668
#   * AMIE Tanh model error: {} [[-0.2473466], [0.2473466]]
#   * Taylor Tanh model error: {} [[-9.22101598e+19], [9.22101598e+19]]
#   * Analyzing domain width 2
#   * v_max suggestion: 13.637144943062394
#   * AMIE Tanh model error: {} [[-0.30738702], [0.30738702]]
#   * Taylor Tanh model error: {} [[-4.86483688e+21], [4.86483688e+21]]
#
# Performing range analysis on network 3
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.63817463012653
#   * AMIE Tanh model error: {} [[-0.02990788], [0.02990788]]
#   * Taylor Tanh model error: {} [[-7.46414371e+10], [7.46414371e+10]]
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:704: RuntimeWarning: overflow encountered in square
#   interval_result.x1 = interval.x2 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:705: RuntimeWarning: overflow encountered in square
#   interval_result.x2 = interval.x1 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:714: RuntimeWarning: overflow encountered in square
#   interval.x1 ** integer_exponent_even,
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:715: RuntimeWarning: overflow encountered in square
#   interval.x2 ** integer_exponent_even,
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:729: RuntimeWarning: overflow encountered in square
#   interval_result.x1 = interval.x1 ** integer_exponent_even
# c:\users\sanch\engineering\projects\verified_computing\src\verified_computing\intvmath.py:730: RuntimeWarning: overflow encountered in square
#   interval_result.x2 = interval.x2 ** integer_exponent_even
#   * Analyzing domain width 0.1
#   * v_max suggestion: 5.007884885346121
#   * AMIE Tanh model error: {} [[-0.03906856], [0.03906856]]
#   * Taylor Tanh model error: {} [[-4.42026102e+11], [4.42026102e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.614445003436879
#   * AMIE Tanh model error: {} [[-0.08755787], [0.08755787]]
#   * Taylor Tanh model error: {} [[-2.76486784e+14], [2.76486784e+14]]
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\numpy\core\function_base.py:146: RuntimeWarning: invalid value encountered in multiply
#   y = y * step
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\numpy\core\function_base.py:154: RuntimeWarning: invalid value encountered in add
#   y += start
#   * Analyzing domain width 1
#   * v_max suggestion: 9.354357083603375
#   * AMIE Tanh model error: {} [[-0.1802796], [0.1802796]]
#   * Taylor Tanh model error: {} [[-8.22994789e+17], [8.22994789e+17]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 10.76630949114515
#   * AMIE Tanh model error: {} [[-0.22565516], [0.22565516]]
#   * Taylor Tanh model error: {} [[-2.10156632e+19], [2.10156632e+19]]
#   * Analyzing domain width 2
#   * v_max suggestion: 14.282888484739487
#   * AMIE Tanh model error: {} [[-0.32377181], [0.32377181]]
#   * Taylor Tanh model error: {} [[-1.41156438e+22], [1.41156438e+22]]
#
# Performing range analysis on network 4
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.424144958595306
#   * AMIE Tanh model error: {} [[-0.0250924], [0.0250924]]
#   * Taylor Tanh model error: {} [[-2.492677e+10], [2.492677e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.672937754936974
#   * AMIE Tanh model error: {} [[-0.03072533], [0.03072533]]
#   * Taylor Tanh model error: {} [[-8.87625131e+10], [8.87625131e+10]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.143103268861757
#   * AMIE Tanh model error: {} [[-0.07227684], [0.07227684]]
#   * Taylor Tanh model error: {} [[-5.00687788e+13], [5.00687788e+13]]
#   * Analyzing domain width 1
#   * v_max suggestion: 8.159878132369187
#   * AMIE Tanh model error: {} [[-0.13996076], [0.13996076]]
#   * Taylor Tanh model error: {} [[-3.52431496e+16], [3.52431496e+16]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 10.075588242035774
#   * AMIE Tanh model error: {} [[-0.20383897], [0.20383897]]
#   * Taylor Tanh model error: {} [[-4.55977095e+18], [4.55977095e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 12.450726956006857
#   * AMIE Tanh model error: {} [[-0.2753937], [0.2753937]]
#   * Taylor Tanh model error: {} [[-5.98099171e+20], [5.98099171e+20]]
#
# Performing range analysis on network 5
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.570600873393856
#   * AMIE Tanh model error: {} [[-0.0283466], [0.0283466]]
#   * Taylor Tanh model error: {} [[-5.30949958e+10], [5.30949958e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.852039462623988
#   * AMIE Tanh model error: {} [[-0.03508458], [0.03508458]]
#   * Taylor Tanh model error: {} [[-2.12386014e+11], [2.12386014e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.668614953902429
#   * AMIE Tanh model error: {} [[-0.08934916], [0.08934916]]
#   * Taylor Tanh model error: {} [[-3.33826663e+14], [3.33826663e+14]]
#   * Analyzing domain width 1
#   * v_max suggestion: 8.669524615092936
#   * AMIE Tanh model error: {} [[-0.15731013], [0.15731013]]
#   * Taylor Tanh model error: {} [[-1.42566118e+17], [1.42566118e+17]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 12.725777364349605
#   * AMIE Tanh model error: {} [[-0.28303311], [0.28303311]]
#   * Taylor Tanh model error: {} [[-9.89293873e+20], [9.89293873e+20]]
#   * Analyzing domain width 2
#   * v_max suggestion: 13.652144722485188
#   * AMIE Tanh model error: {} [[-0.3077757], [0.3077757]]
#   * Taylor Tanh model error: {} [[-4.98955247e+21], [4.98955247e+21]]
#
# Performing range analysis on network 6
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.4729725240040725
#   * AMIE Tanh model error: {} [[-0.02615721], [0.02615721]]
#   * Taylor Tanh model error: {} [[-3.21633475e+10], [3.21633475e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.751346515439971
#   * AMIE Tanh model error: {} [[-0.0326038], [0.0326038]]
#   * Taylor Tanh model error: {} [[-1.3058386e+11], [1.3058386e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.340601894541183
#   * AMIE Tanh model error: {} [[-0.07860611], [0.07860611]]
#   * Taylor Tanh model error: {} [[-1.04060524e+14], [1.04060524e+14]]
#   * Analyzing domain width 1
#   * v_max suggestion: 7.950726691781293
#   * AMIE Tanh model error: {} [[-0.13280817], [0.13280817]]
#   * Taylor Tanh model error: {} [[-1.93589052e+16], [1.93589052e+16]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 9.28332379506552
#   * AMIE Tanh model error: {} [[-0.17792123], [0.17792123]]
#   * Taylor Tanh model error: {} [[-6.90357282e+17], [6.90357282e+17]]
#   * Analyzing domain width 2
#   * v_max suggestion: 12.208240253251535
#   * AMIE Tanh model error: {} [[-0.26854613], [0.26854613]]
#   * Taylor Tanh model error: {} [[-3.80226643e+20], [3.80226643e+20]]
#
# Performing range analysis on network 7
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.389904042962705
#   * AMIE Tanh model error: {} [[-0.02435795], [0.02435795]]
#   * Taylor Tanh model error: {} [[-2.08111408e+10], [2.08111408e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.633067250689334
#   * AMIE Tanh model error: {} [[-0.02978859], [0.02978859]]
#   * Taylor Tanh model error: {} [[-7.2757223e+10], [7.2757223e+10]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 5.716978988741296
#   * AMIE Tanh model error: {} [[-0.05908606], [0.05908606]]
#   * Taylor Tanh model error: {} [[-9.49242288e+12], [9.49242288e+12]]
#   * Analyzing domain width 1
#   * v_max suggestion: 7.314048262580773
#   * AMIE Tanh model error: {} [[-0.11105774], [0.11105774]]
#   * Taylor Tanh model error: {} [[-2.81967989e+15], [2.81967989e+15]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 9.859762562654597
#   * AMIE Tanh model error: {} [[-0.19686708], [0.19686708]]
#   * Taylor Tanh model error: {} [[-2.76819213e+18], [2.76819213e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 11.215815926429723
#   * AMIE Tanh model error: {} [[-0.23942088], [0.23942088]]
#   * Taylor Tanh model error: {} [[-5.39295765e+19], [5.39295765e+19]]
#
# Performing range analysis on network 8
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.455989695603029
#   * AMIE Tanh model error: {} [[-0.02578454], [0.02578454]]
#   * Taylor Tanh model error: {} [[-2.94442206e+10], [2.94442206e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.693923171589376
#   * AMIE Tanh model error: {} [[-0.03122341], [0.03122341]]
#   * Taylor Tanh model error: {} [[-9.84874034e+10], [9.84874034e+10]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.084410785365853
#   * AMIE Tanh model error: {} [[-0.07041974], [0.07041974]]
#   * Taylor Tanh model error: {} [[-4.01011644e+13], [4.01011644e+13]]
#   * Analyzing domain width 1
#   * v_max suggestion: 7.9330258049924955
#   * AMIE Tanh model error: {} [[-0.13220248], [0.13220248]]
#   * Taylor Tanh model error: {} [[-1.83884399e+16], [1.83884399e+16]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 10.203127505816834
#   * AMIE Tanh model error: {} [[-0.20792532], [0.20792532]]
#   * Taylor Tanh model error: {} [[-6.09320642e+18], [6.09320642e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 12.123437874196183
#   * AMIE Tanh model error: {} [[-0.26612645], [0.26612645]]
#   * Taylor Tanh model error: {} [[-3.2382913e+20], [3.2382913e+20]]
#
# Performing range analysis on network 9
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.609537839700796
#   * AMIE Tanh model error: {} [[-0.02924172], [0.02924172]]
#   * Taylor Tanh model error: {} [[-6.46487349e+10], [6.46487349e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.815696775201074
#   * AMIE Tanh model error: {} [[-0.03418051], [0.03418051]]
#   * Taylor Tanh model error: {} [[-1.78403259e+11], [1.78403259e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.2417544198562025
#   * AMIE Tanh model error: {} [[-0.07542354], [0.07542354]]
#   * Taylor Tanh model error: {} [[-7.2366481e+13], [7.2366481e+13]]
#   * Analyzing domain width 1
#   * v_max suggestion: 9.010255379814645
#   * AMIE Tanh model error: {} [[-0.16879987], [0.16879987]]
#   * Taylor Tanh model error: {} [[-3.46819569e+17], [3.46819569e+17]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 10.975365519585694
#   * AMIE Tanh model error: {} [[-0.23210091], [0.23210091]]
#   * Taylor Tanh model error: {} [[-3.27328516e+19], [3.27328516e+19]]
#   * Analyzing domain width 2
#   * v_max suggestion: 12.884304094406861
#   * AMIE Tanh model error: {} [[-0.28737471], [0.28737471]]
#   * Taylor Tanh model error: {} [[-1.31567187e+21], [1.31567187e+21]]
#
# Performing range analysis on network 10
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.521283654984328
#   * AMIE Tanh model error: {} [[-0.02723068], [0.02723068]]
#   * Taylor Tanh model error: {} [[-4.12746085e+10], [4.12746085e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.829835487770151
#   * AMIE Tanh model error: {} [[-0.03453107], [0.03453107]]
#   * Taylor Tanh model error: {} [[-1.90954862e+11], [1.90954862e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.4479851889699855
#   * AMIE Tanh model error: {} [[-0.08209426], [0.08209426]]
#   * Taylor Tanh model error: {} [[-1.53414999e+14], [1.53414999e+14]]
#   * Analyzing domain width 1
#   * v_max suggestion: 8.504976857436237
#   * AMIE Tanh model error: {} [[-0.15172604], [0.15172604]]
#   * Taylor Tanh model error: {} [[-9.16363862e+16], [9.16363862e+16]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 8.909187375047932
#   * AMIE Tanh model error: {} [[-0.1654033], [0.1654033]]
#   * Taylor Tanh model error: {} [[-2.67383272e+17], [2.67383272e+17]]
#   * Analyzing domain width 2
#   * v_max suggestion: 12.72485050627339
#   * AMIE Tanh model error: {} [[-0.2830076], [0.2830076]]
#   * Taylor Tanh model error: {} [[-9.87635814e+20], [9.87635814e+20]]
#
# Performing range analysis on network 11
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.432450624280701
#   * AMIE Tanh model error: {} [[-0.02527208], [0.02527208]]
#   * Taylor Tanh model error: {} [[-2.60365188e+10], [2.60365188e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.735527448886819
#   * AMIE Tanh model error: {} [[-0.03222099], [0.03222099]]
#   * Taylor Tanh model error: {} [[-1.20862416e+11], [1.20862416e+11]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.03502803957765
#   * AMIE Tanh model error: {} [[-0.06886639], [0.06886639]]
#   * Taylor Tanh model error: {} [[-3.32130587e+13], [3.32130587e+13]]
#   * Analyzing domain width 1
#   * v_max suggestion: 7.619300274197184
#   * AMIE Tanh model error: {} [[-0.12146959], [0.12146959]]
#   * Taylor Tanh model error: {} [[-7.24641322e+15], [7.24641322e+15]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 9.923978858584729
#   * AMIE Tanh model error: {} [[-0.19894881], [0.19894881]]
#   * Taylor Tanh model error: {} [[-3.21499662e+18], [3.21499662e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 11.918245786558044
#   * AMIE Tanh model error: {} [[-0.26021811], [0.26021811]]
#   * Taylor Tanh model error: {} [[-2.18553377e+20], [2.18553377e+20]]
#
# Performing range analysis on network 12
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.346847074568461
#   * AMIE Tanh model error: {} [[-0.02344894], [0.02344894]]
#   * Taylor Tanh model error: {} [[-1.65523746e+10], [1.65523746e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.570306861931178
#   * AMIE Tanh model error: {} [[-0.02833988], [0.02833988]]
#   * Taylor Tanh model error: {} [[-5.3015776e+10], [5.3015776e+10]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.108710647844465
#   * AMIE Tanh model error: {} [[-0.07118721], [0.07118721]]
#   * Taylor Tanh model error: {} [[-4.39730027e+13], [4.39730027e+13]]
#   * Analyzing domain width 1
#   * v_max suggestion: 7.386858940170285
#   * AMIE Tanh model error: {} [[-0.11353621], [0.11353621]]
#   * Taylor Tanh model error: {} [[-3.54422447e+15], [3.54422447e+15]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 10.074363077946504
#   * AMIE Tanh model error: {} [[-0.2037996], [0.2037996]]
#   * Taylor Tanh model error: {} [[-4.54700926e+18], [4.54700926e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 11.134988018845565
#   * AMIE Tanh model error: {} [[-0.23697154], [0.23697154]]
#   * Taylor Tanh model error: {} [[-4.56519738e+19], [4.56519738e+19]]
#
# Performing range analysis on network 13
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 4.3906348013215215
#   * AMIE Tanh model error: {} [[-0.02437351], [0.02437351]]
#   * Taylor Tanh model error: {} [[-2.08917549e+10], [2.08917549e+10]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 4.628669348305747
#   * AMIE Tanh model error: {} [[-0.02968604], [0.02968604]]
#   * Taylor Tanh model error: {} [[-7.11712725e+10], [7.11712725e+10]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 5.735888202963329
#   * AMIE Tanh model error: {} [[-0.05965575], [0.05965575]]
#   * Taylor Tanh model error: {} [[-1.02461727e+13], [1.02461727e+13]]
#   * Analyzing domain width 1
#   * v_max suggestion: 8.096417722872346
#   * AMIE Tanh model error: {} [[-0.13779163], [0.13779163]]
#   * Taylor Tanh model error: {} [[-2.94335701e+16], [2.94335701e+16]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 10.172210484967469
#   * AMIE Tanh model error: {} [[-0.20693708], [0.20693708]]
#   * Taylor Tanh model error: {} [[-5.68160759e+18], [5.68160759e+18]]
#   * Analyzing domain width 2
#   * v_max suggestion: 11.238307935257101
#   * AMIE Tanh model error: {} [[-0.24010041], [0.24010041]]
#   * Taylor Tanh model error: {} [[-5.64770076e+19], [5.64770076e+19]]
#
# Performing range analysis on network 14
#
#   * Analyzing domain width 0.01
#   * v_max suggestion: 5.104155949334565
#   * AMIE Tanh model error: {} [[-0.04161256], [0.04161256]]
#   * Taylor Tanh model error: {} [[-6.87234116e+11], [6.87234116e+11]]
#   * Analyzing domain width 0.1
#   * v_max suggestion: 5.3035358727635025
#   * AMIE Tanh model error: {} [[-0.047068], [0.047068]]
#   * Taylor Tanh model error: {} [[-1.66971275e+12], [1.66971275e+12]]
#   * Analyzing domain width 0.5
#   * v_max suggestion: 6.5283949822869225
#   * AMIE Tanh model error: {} [[-0.08472544], [0.08472544]]
#   * Taylor Tanh model error: {} [[-2.04295533e+14], [2.04295533e+14]]
#   * Analyzing domain width 1
#   * v_max suggestion: 9.518408378556012
#   * AMIE Tanh model error: {} [[-0.18570179], [0.18570179]]
#   * Taylor Tanh model error: {} [[-1.2287492e+18], [1.2287492e+18]]
#   * Analyzing domain width 1.5
#   * v_max suggestion: 12.141237872071574
#   * AMIE Tanh model error: {} [[-0.26663541], [0.26663541]]
#   * Taylor Tanh model error: {} [[-3.34959257e+20], [3.34959257e+20]]
#   * Analyzing domain width 2
#   * v_max suggestion: 13.583422726166416
#   * AMIE Tanh model error: {} [[-0.30599177], [0.30599177]]
#   * Taylor Tanh model error: {} [[-4.44217533e+21], [4.44217533e+21]]

# %%
# Copy the original dataframe
results_df_orign = results_df.copy(deep=True)

results_df.head(20)
# Out:
#    activation  n_inputs  n_hidden_nodes_per_layer  n_layers  \
# 0        tanh         3                        25         3
# 1        tanh         3                        25         3
# 2        tanh         3                        25         3
# 3        tanh         3                        25         3
# 4        tanh         3                        25         3
# 5        tanh         3                        25         3
# 6        tanh         3                        25         3
# 7        tanh         3                        25         3
# 8        tanh         3                        25         3
# 9        tanh         3                        25         3
# 10       tanh         3                        25         3
# 11       tanh         3                        25         3
# 12       tanh         3                        25         3
# 13       tanh         3                        25         3
# 14       tanh         3                        25         3
# 15       tanh         3                        25         3
# 16       tanh         3                        25         3
# 17       tanh         3                        25         3
# 18       tanh         3                        25         4
# 19       tanh         3                        25         4
#
#     min_range_numerical  max_range_numerical            min_range_taylor  \
# 0              0.341777             0.343388  [-1.5670255345545427e+255]
# 1              0.335786             0.348504  [-1.1006160853366893e+265]
# 2              0.308312             0.376962                      [-inf]
# 3              0.270448             0.401550                      [-inf]
# 4              0.232426             0.419994                      [-inf]
# 5              0.211033             0.443885                      [-inf]
# 6              0.077345             0.078289   [-4.658823545528229e+250]
# 7              0.073657             0.082259   [-8.135529402063882e+259]
# 8              0.053414             0.105209                      [-inf]
# 9              0.033301             0.132622                      [-inf]
# 10             0.025876             0.163772                      [-inf]
# 11            -0.003274             0.188557                      [-inf]
# 12             0.162298             0.163046   [-1.547480623221737e+249]
# 13             0.159535             0.165755   [-5.371914111750836e+260]
# 14             0.145050             0.176764                      [-inf]
# 15             0.124582             0.195127                      [-inf]
# 16             0.111948             0.224531                      [-inf]
# 17             0.099914             0.226742                      [-inf]
# 18             0.029026             0.030421                      [-inf]
# 19             0.022237             0.037043                      [-inf]
#
#              max_range_taylor          min_range_amie         max_range_amie  \
# 0   [1.5670255345505502e+255]   [0.05165737789582264]   [0.5916493412054787]
# 1   [1.1006160853356255e+265]  [-0.16020438840195084]   [0.7947350706422919]
# 2                       [inf]   [-1.0349958635204783]   [1.6065440142203902]
# 3                       [inf]   [-1.7717361220351655]    [2.277313322524156]
# 4                       [inf]    [-2.195909723405354]   [2.6678317448054187]
# 5                       [inf]   [-2.4718267522371744]   [2.9229747424447012]
# 6    [4.658823545872227e+250]  [-0.15413524368123346]  [0.32294321973947804]
# 7    [8.135529402301937e+259]  [-0.36881103157375683]   [0.5397245058778135]
# 8                       [inf]   [-1.2683110024236373]   [1.4554613877452318]
# 9                       [inf]   [-1.8954727295849871]   [2.0882778528911095]
# 10                      [inf]    [-2.297627628128451]   [2.4937675546240694]
# 11                      [inf]   [-2.5393436366370543]   [2.7358403892299386]
# 12  [1.5474806233123023e+249]  [-0.06961863023133236]   [0.3890977573147626]
# 13   [5.371914111849861e+260]  [-0.29422262552603445]    [0.613953683851767]
# 14                      [inf]   [-1.1447026562945215]   [1.4694030397148308]
# 15                      [inf]   [-1.8758327233756291]   [2.1978015471600214]
# 16                      [inf]    [-2.230294227348289]   [2.5500275126004954]
# 17                      [inf]   [-2.4332588096176444]    [2.751487657113032]
# 18                      [inf]   [-0.6980063844701687]    [0.793653635799315]
# 19                      [inf]   [-1.2939459800767996]   [1.4096767827806647]
#
#         overestimation_taylor    overestimation_amie  \
# 0    [3.134051069105093e+255]   [0.5383805620203205]
# 1   [2.2012321706723146e+265]   [0.9422216366136521]
# 2                       [inf]    [2.572890158866701]
# 3                       [inf]   [3.9179470797308165]
# 4                       [inf]    [4.676173716654009]
# 5                       [inf]     [5.16194953905228]
# 6    [9.317647091400457e+250]  [0.47613475239648156]
# 7    [1.627105880436582e+260]   [0.8999333777625952]
# 8                       [inf]    [2.671977337057121]
# 9                       [inf]   [3.8844295340642945]
# 10                      [inf]    [4.653499094567512]
# 11                      [inf]    [5.083353728731665]
# 12  [3.0949612465340392e+249]  [0.45796816528084294]
# 13  [1.0743828223600697e+261]    [0.901956492704179]
# 14                      [inf]    [2.582391743076413]
# 15                      [inf]    [4.003088723921259]
# 16                      [inf]    [4.667738260736283]
# 17                      [inf]    [5.057918725786027]
# 18                      [inf]   [1.4902643904955213]
# 19                      [inf]      [2.6888163818658]
#
#     runtime_to_generate_amie_coefs  runtime_to_range_bound_via_amie  \
# 0                         1.984537                         2.328134
# 1                         1.959459                         2.363032
# 2                         3.081306                         2.341276
# 3                         2.748931                         2.331496
# 4                         3.271413                         2.319635
# 5                         3.346519                         2.307797
# 6                         1.895117                         2.307428
# 7                         1.909887                         2.287990
# 8                         3.025444                         2.299314
# 9                         2.596890                         2.284953
# 10                        3.224945                         2.332638
# 11                        3.387594                         2.247958
# 12                        1.886401                         2.292180
# 13                        2.431945                         2.260857
# 14                        2.981298                         2.307733
# 15                        2.737276                         2.304203
# 16                        3.376092                         2.329014
# 17                        3.595810                         2.307183
# 18                        1.913502                         3.426783
# 19                        2.465754                         3.370079
#
#     domain_interval_width
# 0                    0.01
# 1                    0.10
# 2                    0.50
# 3                    1.00
# 4                    1.50
# 5                    2.00
# 6                    0.01
# 7                    0.10
# 8                    0.50
# 9                    1.00
# 10                   1.50
# 11                   2.00
# 12                   0.01
# 13                   0.10
# 14                   0.50
# 15                   1.00
# 16                   1.50
# 17                   2.00
# 18                   0.01
# 19                   0.10

# %%
# Remove outliers due to Taylor divergence
inf_threshold = 1000
results_df.loc[results_df['overestimation_taylor'] > inf_threshold, 'overestimation_taylor'] = np.inf

results_df.loc[results_df['overestimation_amie'] > inf_threshold, 'overestimation_amie']
# Out:
# Series([], Name: overestimation_amie, dtype: object)

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_interval_width_amie.png',
    results_df,
    xcol='domain_interval_width', ycol='overestimation_amie',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='Domain Interval Width')

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_n_layers_amie.png',
    results_df,
    xcol='n_layers', ycol='overestimation_amie',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='N. Layers')

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_interval_width_taylor.png',
    results_df,
    xcol='domain_interval_width', ycol='overestimation_taylor',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='Domain Interval Width')
# Out:
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\numpy\lib\function_base.py:3968: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\matplotlib\cbook\__init__.py:1211: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\matplotlib\cbook\__init__.py:1218: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]

# %%
boxplot_utils.make_boxplot(
    'plots/overestimation_wrt_n_layers_taylor.png',
    results_df,
    xcol='n_layers', ycol='overestimation_taylor',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='N. Layers')
# Out:
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\matplotlib\cbook\__init__.py:1211: RuntimeWarning: invalid value encountered in less_equal
#   wiskhi = x[x <= hival]
# C:\Users\sanch\anaconda3\envs\cuda111\lib\site-packages\matplotlib\cbook\__init__.py:1218: RuntimeWarning: invalid value encountered in greater_equal
#   wisklo = x[x >= loval]

# %%
boxplot_utils.make_boxplot(
    'plots/runtime_range_bound_wrt_n_layers.png',
    results_df,
    xcol='n_layers', ycol='runtime_to_range_bound_via_amie',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='N. Layers')

# %%
boxplot_utils.make_boxplot(
    'plots/runtime_generate_coefs_wrt_interval_width.png',
    results_df,
    xcol='domain_interval_width', ycol='runtime_to_generate_amie_coefs',
    lw=1.75, color='k',
    figsize=(9,4), fontsize=15,
    xlabel='Domain Interval Width')
