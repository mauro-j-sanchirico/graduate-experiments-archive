# %%
# Wolfram Language Imports
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl, wlexpr
ws = WolframLanguageSession()

# %%
# Display Latex
from IPython.display import display, Math

# Display Plots
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def print_tex(expr):
    """Prints an expression in latex"""
    display(Math(expr))

def print_wlresult(expr):
    """Prints a wolfram language result in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(expr)))
    display(Math(tex_expr))

def print_wlexpr(expr):
    """Prints a wolfram language expression in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(ws.evaluate(expr))))
    display(Math(tex_expr))
    
def wc(expr):
    """Evaluates an expression, stores, and prints the result"""
    result = ws.evaluate(expr)
    save_expr_str = 'rrr = {}'.format(expr)
    ws.evaluate(save_expr_str)
    print_wlresult(ws.evaluate('rrr'))
    return result

def wplot(filename, command):
    export_expr = 'Export["{}", {}]'.format(filename, command)
    wc(export_expr)
    img = mpimg.imread(filename)
    imgplot = plt.imshow(img)
    plt.show()
    plt.axis('off')

# %% [markdown]
# ## Single Layer, Single Output Expansion

# %%
wc('''
v = b + w1*x1 + w2*x2;
alpha = {a0, a1, a2, a3, a4}
y = Sum[Part[alpha, i+1]*v^i, {i, 0, 4}]
''')

wc('''
Expand[y]
''')
# Out:
# $\displaystyle b+\text{w1} \text{x1}+\text{w2} \text{x2}$
# $\displaystyle \text{a0}+\text{a1} b+\text{a1} \text{w1} \text{x1}+\text{a1} \text{w2} \text{x2}+\text{a2} b^2+2 \text{a2} b \text{w1} \text{x1}+2 \text{a2} b \text{w2} \text{x2}+\text{a2} \text{w1}^2 \text{x1}^2+2 \text{a2} \text{w1} \text{w2} \text{x1} \text{x2}+\text{a2} \text{w2}^2 \text{x2}^2+3 \text{a3} b^2 \text{w1} \text{x1}+3 \text{a3} b^2 \text{w2} \text{x2}+\text{a3} b^3+3 \text{a3} b \text{w1}^2 \text{x1}^2+6 \text{a3} b \text{w1} \text{w2} \text{x1} \text{x2}+3 \text{a3} b \text{w2}^2 \text{x2}^2+3 \text{a3} \text{w1}^2 \text{w2} \text{x1}^2 \text{x2}+\text{a3} \text{w1}^3 \text{x1}^3+3 \text{a3} \text{w1} \text{w2}^2 \text{x1} \text{x2}^2+\text{a3} \text{w2}^3 \text{x2}^3+6 \text{a4} b^2 \text{w1}^2 \text{x1}^2+12 \text{a4} b^2 \text{w1} \text{w2} \text{x1} \text{x2}+4 \text{a4} b^3 \text{w1} \text{x1}+6 \text{a4} b^2 \text{w2}^2 \text{x2}^2+4 \text{a4} b^3 \text{w2} \text{x2}+\text{a4} b^4+12 \text{a4} b \text{w1}^2 \text{w2} \text{x1}^2 \text{x2}+4 \text{a4} b \text{w1}^3 \text{x1}^3+12 \text{a4} b \text{w1} \text{w2}^2 \text{x1} \text{x2}^2+4 \text{a4} b \text{w2}^3 \text{x2}^3+6 \text{a4} \text{w1}^2 \text{w2}^2 \text{x1}^2 \text{x2}^2+4 \text{a4} \text{w1}^3 \text{w2} \text{x1}^3 \text{x2}+\text{a4} \text{w1}^4 \text{x1}^4+4 \text{a4} \text{w1} \text{w2}^3 \text{x1} \text{x2}^3+\text{a4} \text{w2}^4 \text{x2}^4$
# Plus[Global`a0, Times[Global`a1, Global`b], << 31 >>, Times[4, Global`a4, << 2 >>, Global`x1, Power[Global`x2, 3]], Times[Global`a4, Power[Global`w2, 4], Power[Global`x2, 4]]]

# %%
wc('''Expand[(b + x1*w1 + x2*w2)^4]''')
# Out:
# $\displaystyle 6 b^2 \text{w1}^2 \text{x1}^2+12 b^2 \text{w1} \text{w2} \text{x1} \text{x2}+4 b^3 \text{w1} \text{x1}+6 b^2 \text{w2}^2 \text{x2}^2+4 b^3 \text{w2} \text{x2}+b^4+12 b \text{w1}^2 \text{w2} \text{x1}^2 \text{x2}+4 b \text{w1}^3 \text{x1}^3+12 b \text{w1} \text{w2}^2 \text{x1} \text{x2}^2+4 b \text{w2}^3 \text{x2}^3+6 \text{w1}^2 \text{w2}^2 \text{x1}^2 \text{x2}^2+4 \text{w1}^3 \text{w2} \text{x1}^3 \text{x2}+\text{w1}^4 \text{x1}^4+4 \text{w1} \text{w2}^3 \text{x1} \text{x2}^3+\text{w2}^4 \text{x2}^4$
# Plus[Power[Global`b, 4], Times[4, Power[Global`b, 3], Global`w1, Global`x1], << 11 >>, Times[4, Global`w1, << 1 >>, Global`x1, Power[Global`x2, 3]], Times[Power[Global`w2, 4], Power[Global`x2, 4]]]

# %%
wc('''1+3+6+10+15+21''')
# Out:
# $\displaystyle 56$
# 56
