# %%
# Wolfram Language Imports
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl, wlexpr
ws = WolframLanguageSession()

# %%
# Display Latex
from IPython.display import display, Math

# Display Plots
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def print_tex(expr):
    """Prints an expression in latex"""
    display(Math(expr))

def print_wlresult(expr):
    """Prints a wolfram language result in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(expr)))
    display(Math(tex_expr))

def print_wlexpr(expr):
    """Prints a wolfram language expression in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(ws.evaluate(expr))))
    display(Math(tex_expr))
    
def wc(expr):
    """Evaluates an expression, stores, and prints the result"""
    result = ws.evaluate(expr)
    save_expr_str = 'rrr = {}'.format(expr)
    ws.evaluate(save_expr_str)
    print_wlresult(ws.evaluate('rrr'))
    return result

def wplot(filename, command):
    export_expr = 'Export["{}", {}]'.format(filename, command)
    wc(export_expr)
    img = mpimg.imread(filename)
    imgplot = plt.imshow(img)
    plt.show()
    plt.axis('off')

# %%
wc('''
ListConvolve[{a, b}, {0, a, b, 0}];
''')
# Out:
# $\displaystyle \left\{a^2,2 a b,b^2\right\}$

# %%
wc('''
ListConvolve[{a, b, c}, {0, 0, a, b, c, 0, 0}]
FullSimplify[Total[ListConvolve[{a, b, c}, {0, 0, a, b, c, 0, 0}]] - (a+b+c)^2]
''')
# Out:
# $\displaystyle \left\{a^2,2 a b,2 a c+b^2,2 b c,c^2\right\}$
# 0

# %%
wc('''
ListConvolve[{a, b, c, d}, {a, b, c, d}, 1]
FullSimplify[Total[ListConvolve[{a, b, c, d}, {0, 0, 0, a, b, c, d, 0, 0, 0}]] - (a+b+c+d)^2]
''')
# Out:
# $\displaystyle \left\{a^2+2 b d+c^2,2 a b+2 c d,2 a c+b^2+d^2,2 a d+2 b c\right\}$
# 0

# %%
wc('''
{
Expand[(a+b)^2],
Expand[(a+b)^3],
Expand[(a+b)^n]
}
''')
# Out:
# $\displaystyle \left\{a^2+2 a b+b^2,3 a^2 b+a^3+3 a b^2+b^3,(a+b)^n\right\}$
# (Plus[Power[Global`a, 2], Times[2, Global`a, Global`b], Power[Global`b, 2]],
#  Plus[Power[Global`a, 3], Times[3, Power[Global`a, 2], Global`b], Times[3, Global`a, Power[Global`b, 2]], Power[Global`b, 3]],
#  Power[Plus[Global`a, Global`b], Global`n])

# %%
wc('''
NI = 3;
{Sum[Binomial[j + NI, NI], {j, 0, i}]} /. i -> {0,1,2,3,4,5,6,7,8}
''')
# Out:
# $\displaystyle 3$
# ((1, 5, 15, 35, 70, 126, 210, 330, 495),)

# %%
wc('Expand[(w1*x1 + w2*x2 + w3*x3)^1]')
wc('Expand[(w1*x1 + w2*x2 + w3*x3)^2]')
wc('Expand[(w1*x1 + w2*x2 + w3*x3)^3]')
# Out:
# $\displaystyle \text{w1} \text{x1}+\text{w2} \text{x2}+\text{w3} \text{x3}$
# $\displaystyle \text{w1}^2 \text{x1}^2+2 \text{w1} \text{w2} \text{x1} \text{x2}+2 \text{w1} \text{w3} \text{x1} \text{x3}+\text{w2}^2 \text{x2}^2+2 \text{w2} \text{w3} \text{x2} \text{x3}+\text{w3}^2 \text{x3}^2$
# $\displaystyle 3 \text{w1}^2 \text{w2} \text{x1}^2 \text{x2}+3 \text{w1}^2 \text{w3} \text{x1}^2 \text{x3}+\text{w1}^3 \text{x1}^3+3 \text{w1} \text{w2}^2 \text{x1} \text{x2}^2+6 \text{w1} \text{w2} \text{w3} \text{x1} \text{x2} \text{x3}+3 \text{w1} \text{w3}^2 \text{x1} \text{x3}^2+3 \text{w2}^2 \text{w3} \text{x2}^2 \text{x3}+\text{w2}^3 \text{x2}^3+3 \text{w2} \text{w3}^2 \text{x2} \text{x3}^2+\text{w3}^3 \text{x3}^3$
# Plus[Times[Power[Global`w1, 3], Power[Global`x1, 3]], Times[3, Power[Global`w1, 2], << 1 >>, Power[Global`x1, 2], Global`x2], << 6 >>, Times[3, Global`w2, << 1 >>, Global`x2, Power[Global`x3, 2]], Times[Power[Global`w3, 3], Power[Global`x3, 3]]]

# %%
wc('''
Expand[FullSimplify[(1 + x + 1/2 * x^2)*(1 - 1/2 * x^2)]]
''')
# Out:
# $\displaystyle -\frac{x^4}{4}-\frac{x^3}{2}+x+1$
# Plus[1, Global`x, Times[Rational[-1, 2], Power[Global`x, 3]], Times[Rational[-1, 4], Power[Global`x, 4]]]
