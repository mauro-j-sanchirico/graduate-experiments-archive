# %%
# Wolfram Language Imports
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl, wlexpr
ws = WolframLanguageSession()

# %%
# Display Latex
from IPython.display import display, Math

# Display Plots
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def print_tex(expr):
    """Prints an expression in latex"""
    display(Math(expr))

def print_wlresult(expr):
    """Prints a wolfram language result in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(expr)))
    display(Math(tex_expr))

def print_wlexpr(expr):
    """Prints a wolfram language expression in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(ws.evaluate(expr))))
    display(Math(tex_expr))

def print_wlexpr_latex(expr):
    """Prints a wolfram language expression in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(ws.evaluate(expr))))
    print(tex_expr)
    
def wc(expr):
    """Evaluates an expression, stores, and prints the result"""
    result = ws.evaluate(expr)
    save_expr_str = 'rrr = {}'.format(expr)
    ws.evaluate(save_expr_str)
    print_wlresult(ws.evaluate('rrr'))
    return result

def wplot(filename, command):
    export_expr = 'Export["{}", {}]'.format(filename, command)
    wc(export_expr)
    img = mpimg.imread(filename)
    imgplot = plt.imshow(img)
    plt.show()
    plt.axis('off')

# %%
wc('''
FullSimplify[Integrate[Tanh[v]^1 * Sin[x*v], v]]
''')
# Out:
# $\displaystyle \frac{1}{4} e^{-i v x} \left(-e^{2 v}\right)^{-\frac{i x}{2}} \left(i e^{2 i v x} \left(B_{-e^{2 v}}\left(\frac{i x}{2}+1,0\right)+B_{-e^{2 v}}\left(\frac{i x}{2},0\right)\right)-i \left(-e^{2 v}\right)^{i x} \left(B_{-e^{2 v}}\left(1-\frac{i x}{2},0\right)+B_{-e^{2 v}}\left(-\frac{i x}{2},0\right)\right)\right)$
# Times[Rational[1, 4], Power[E, Times[Complex[0, -1], Global`v, Global`x]], Power[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[-1, 2]], Global`x]], Plus[Times[Complex[0, -1], Power[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, 1], Global`x]], Plus[Beta[Times[-1, Power[E, Times[2, Global`v]]], Plus[1, Times[Complex[0, Rational[-1, 2]], Global`x]], 0], Beta[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[-1, 2]], Global`x], 0]]], Times[Complex[0, 1], Power[E, Times[Complex[0, 2], Global`v, Global`x]], Plus[Beta[Times[-1, Power[E, Times[2, Global`v]]], Plus[1, Times[Complex[0, Rational[1, 2]], Global`x]], 0], Beta[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[1, 2]], Global`x], 0]]]]]

# %%
wc('''
FullSimplify[Integrate[Tanh[v]^3 * Sin[x*v], v]]
''')
# Out:
# $\displaystyle \frac{1}{16} e^{-i v x} \left(-2 i \left(x^2-2\right) e^{2 i v x} \left(-e^{2 v}\right)^{-\frac{i x}{2}} \left(B_{-e^{2 v}}\left(\frac{i x}{2}+1,0\right)+B_{-e^{2 v}}\left(\frac{i x}{2},0\right)\right)+2 i \left(x^2-2\right) \left(-e^{2 v}\right)^{\frac{i x}{2}} \left(B_{-e^{2 v}}\left(1-\frac{i x}{2},0\right)+B_{-e^{2 v}}\left(-\frac{i x}{2},0\right)\right)-4 x e^{2 i v x} \tanh (v)-4 x \tanh (v)-4 i e^{2 i v x} \text{sech}^2(v)+4 i \text{sech}^2(v)\right)$
# Times[Rational[1, 16], Power[E, Times[Complex[0, -1], Global`v, Global`x]], Plus[Times[Complex[0, 2], Power[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[1, 2]], Global`x]], Plus[-2, Power[Global`x, 2]], Plus[Beta[Times[-1, Power[E, Times[2, Global`v]]], Plus[1, Times[Complex[0, Rational[-1, 2]], Global`x]], 0], Beta[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[-1, 2]], Global`x], 0]]], Times[Complex[0, -2], Power[E, Times[Complex[0, 2], Global`v, Global`x]], << 1 >>, Plus[-2, Power[Global`x, 2]], Plus[Beta[Times[-1, Power[E, Times[2, Global`v]]], Plus[1, Times[Complex[0, Rational[1, 2]], Global`x]], 0], Beta[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[1, 2]], Global`x], 0]]], << 2 >>, Times[-4, Global`x, Tanh[Global`v]], Times[-4, Power[E, Times[Complex[0, 2], Global`v, Global`x]], Global`x, Tanh[Global`v]]]]

# %%
wc('''
FullSimplify[Integrate[Tanh[v]^5 * Sin[x*v], v]]
''')
# Out:
# $\displaystyle \frac{1}{96} e^{-i v x} \left(2 x \left(x^2-20\right) \left(1+e^{2 i v x}\right) \tanh (v)+2 i \left(x^2-24\right) \left(-1+e^{2 i v x}\right) \text{sech}^2(v)+i \left(x^4-20 x^2+24\right) e^{2 i v x} \left(-e^{2 v}\right)^{-\frac{i x}{2}} \left(B_{-e^{2 v}}\left(\frac{i x}{2}+1,0\right)+B_{-e^{2 v}}\left(\frac{i x}{2},0\right)\right)-i \left(x^4-20 x^2+24\right) \left(-e^{2 v}\right)^{\frac{i x}{2}} \left(B_{-e^{2 v}}\left(1-\frac{i x}{2},0\right)+B_{-e^{2 v}}\left(-\frac{i x}{2},0\right)\right)+12 i \left(-1+e^{2 i v x}\right) \text{sech}^4(v)+4 x \left(1+e^{2 i v x}\right) \tanh (v) \text{sech}^2(v)\right)$
# Times[Rational[1, 96], Power[E, Times[Complex[0, -1], Global`v, Global`x]], Plus[Times[Complex[0, -1], Power[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[1, 2]], Global`x]], Plus[24, Times[-20, Power[Global`x, 2]], Power[Global`x, 4]], Plus[Beta[Times[-1, Power[E, Times[2, Global`v]]], Plus[1, Times[Complex[0, Rational[-1, 2]], Global`x]], 0], Beta[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[-1, 2]], Global`x], 0]]], Times[Complex[0, 1], Power[E, Times[Complex[0, 2], Global`v, Global`x]], << 1 >>, Plus[24, Times[-20, Power[Global`x, 2]], Power[Global`x, 4]], Plus[Beta[Times[-1, Power[E, Times[2, Global`v]]], Plus[1, Times[Complex[0, Rational[1, 2]], Global`x]], 0], Beta[Times[-1, Power[E, Times[2, Global`v]]], Times[Complex[0, Rational[1, 2]], Global`x], 0]]], << 2 >>, Times[2, Plus[1, Power[E, Times[Complex[0, 2], Global`v, Global`x]]], << 1 >>, Plus[-20, Power[Global`x, 2]], Tanh[Global`v]], Times[4, Plus[1, Power[E, Times[Complex[0, 2], Global`v, Global`x]]], << 1 >>, Power[Sech[Global`v], 2], Tanh[Global`v]]]]

# %%
wc('''
FullSimplify[Integrate[Tanh[v]^{2*m+1} * Sin[x*v], v, Assumptions -> Element[m, Integers]]]
''')
# Out:
# $\displaystyle \left\{\text{Integrate}\left[\tanh ^{2 m+1}(v) \sin (v x),v,\text{Assumptions}\to m\in \mathbb{Z}\right]\right\}$
# (Integrate[Times[Sin[Times[Global`v, Global`x]], Power[Tanh[Global`v], Plus[1, Times[2, Global`m]]]], Global`v, Rule[Assumptions, Element[Global`m, Integers]]],)

# %%
ws.stop()
