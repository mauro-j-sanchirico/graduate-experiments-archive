# %% [markdown]
# ## Meijer G Table Generator

# %%
# Wolfram Language Imports
from wolframclient.evaluation import WolframLanguageSession
from wolframclient.language import wl, wlexpr
ws = WolframLanguageSession()

# %%
# Display Latex
from IPython.display import display, Math

# Display Plots
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def print_tex(expr):
    """Prints an expression in latex"""
    display(Math(expr))

def print_wlresult(expr):
    """Prints a wolfram language result in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(expr)))
    display(Math(tex_expr))

def print_wlexpr(expr):
    """Prints a wolfram language expression in latex"""
    tex_expr = ws.evaluate(wl.ToString(wl.TeXForm(ws.evaluate(expr))))
    display(Math(tex_expr))
    
def wc(expr):
    """Evaluates an expression, stores, and prints the result"""
    result = ws.evaluate(expr)
    save_expr_str = 'rrr = {}'.format(expr)
    ws.evaluate(save_expr_str)
    print_wlresult(ws.evaluate('rrr'))
    return result

def wplot(filename, command):
    export_expr = 'Export["{}", {}]'.format(filename, command)
    wc(export_expr)
    img = mpimg.imread(filename)
    imgplot = plt.imshow(img)
    plt.show()
    plt.axis('off')

# %%
wc('''
flist = {
a*E^(w*x),
a*Sin[w*x + p], 
a*Cos[w*x + p],
a*Sinh[w*x + p],
a*Cosh[w*x + p],
q*Hypergeometric2F1[a, b, c, x], 
a*UnitStep[w*x],
a*UnitBox[w*x],
UnitStep[x]*x
}; 
''')
# Out:
# $\displaystyle \left\{a e^{w x},a \sin (p+w x),a \cos (p+w x),a \sinh (p+w x),a \cosh (p+w x),q \, _2F_1(a,b;c;x),a \theta (w x),a \Pi (w x),x \theta (x)\right\}$

# %%
wc('''
Grid[
    Join[{{f[x], Text["MeijerG Representation"]}}, 
        Transpose[{flist, Map[MeijerGReduce[#, x] &, flist]}]], 
    Background -> {
        None, 
        {{None, GrayLevel[.9]}}, 
        {{1, 1} -> Hue[.6, .4, 1], {1, 2} -> Hue[.6, .4, 1]}}, 
    BaseStyle -> {FontFamily -> Times, FontSize -> 12},
    Dividers -> All,
    FrameStyle -> Hue[.6, .4, .8], 
    Spacings -> {2, 1}] 
''')
# Out:
# $\displaystyle \begin{array}{|c|c|}
# \hline
#  f(x) & \text{MeijerG Representation} \\
# \hline
#  a e^{w x} & \frac{a \text{MeijerG}\left(\{\{\},\{\}\},\left\{\left\{0,\frac{1}{2}\right\},\{\}\right\},-\frac{w x}{2},\frac{1}{2}\right)}{\sqrt{\pi }} \\
# \hline
#  a \sin (p+w x) & \sqrt{\pi } a \text{MeijerG}\left(\left\{\{\},\left\{\frac{p}{\pi }\right\}\right\},\left\{\left\{0,\frac{1}{2}\right\},\left\{\frac{p}{\pi }\right\}\right\},\frac{w x}{2},\frac{1}{2}\right) \\
# \hline
#  a \cos (p+w x) & \sqrt{\pi } a \text{MeijerG}\left(\left\{\{\},\left\{\frac{p}{\pi }+\frac{1}{2}\right\}\right\},\left\{\left\{0,\frac{1}{2}\right\},\left\{\frac{p}{\pi }+\frac{1}{2}\right\}\right\},\frac{w x}{2},\frac{1}{2}\right) \\
# \hline
#  a \sinh (p+w x) & -i \sqrt{\pi } a \text{MeijerG}\left(\left\{\{\},\left\{\frac{i p}{\pi }\right\}\right\},\left\{\left\{0,\frac{1}{2}\right\},\left\{\frac{i p}{\pi }\right\}\right\},\frac{i w x}{2},\frac{1}{2}\right) \\
# \hline
#  a \cosh (p+w x) & \sqrt{\pi } a \text{MeijerG}\left(\left\{\{\},\left\{\frac{1}{2}+\frac{i p}{\pi }\right\}\right\},\left\{\left\{0,\frac{1}{2}\right\},\left\{\frac{1}{2}+\frac{i p}{\pi }\right\}\right\},\frac{i w x}{2},\frac{1}{2}\right) \\
# \hline
#  q \, _2F_1(a,b;c;x) & \frac{q \Gamma (c) \text{MeijerG}\left(\{\{1-a,1-b\},\{\}\},\left(
# \begin{array}{c}
#  0 \\
#  1-c \\
# \end{array}
# \right),-x\right)}{\Gamma (a) \Gamma (b)} \\
# \hline
#  a \theta (w x) & \fbox{$a \text{MeijerG}(\{\{1\},\{\}\},\{\{\},\{0\}\},w x+1)\text{ if }w x>-2$} \\
# \hline
#  a \Pi (w x) & a \text{MeijerG}(\{\{\},\{1\}\},\{\{0\},\{\}\},2 w x) \\
# \hline
#  x \theta (x) & \fbox{$x \text{MeijerG}(\{\{1\},\{\}\},\{\{\},\{0\}\},x+1)\text{ if }x>-2$} \\
# \hline
# \end{array}$
# Grid[((Global`f[Global`x], Text['MeijerG Representation']), (Times[Global`a, Power[E, Times[Global`w, Global`x]]], Times[Global`a, Power[Pi, Rational[-1, 2]], Inactive[MeijerG][((), ()), ((0, Rational[1, 2]), ()), Times[Rational[-1, 2], Global`w, Global`x], Rational[1, 2]]]), (Times[Global`a, Sin[Plus[Global`p, Times[Global`w, Global`x]]]], Times[Global`a, Power[Pi, Rational[1, 2]], Inactive[MeijerG][((), (Times[Global`p, Power[Pi, -1]],)), ((0, Rational[1, 2]), (Times[Global`p, Power[Pi, -1]],)), Times[Rational[1, 2], Global`w, Global`x], Rational[1, 2]]]), (Times[Global`a, Cos[Plus[Global`p, Times[Global`w, Global`x]]]], Times[Global`a, Power[Pi, Rational[1, 2]], Inactive[MeijerG][((), (Plus[Rational[1, 2], Times[Global`p, Power[Pi, -1]]],)), ((0, Rational[1, 2]), (Plus[Rational[1, 2], Times[Global`p, Power[Pi, -1]]],)), Times[Rational[1, 2], Global`w, Global`x], Rational[1, 2]]]), (Times[Global`a, Sinh[Plus[Global`p, Times[Global`w, Global`x]]]], Times[Complex[0, -1], Global`a, Power[Pi, Rational[1, 2]], Inactive[MeijerG][((), (Times[Complex[0, 1], Global`p, Power[Pi, -1]],)), ((0, Rational[1, 2]), (Times[Complex[0, 1], Global`p, Power[Pi, -1]],)), Times[Complex[0, Rational[1, 2]], Global`w, Global`x], Rational[1, 2]]]), (Times[Global`a, Cosh[Plus[Global`p, Times[Global`w, Global`x]]]], Times[Global`a, Power[Pi, Rational[1, 2]], Inactive[MeijerG][((), (Plus[Rational[1, 2], Times[Complex[0, 1], Global`p, Power[Pi, -1]]],)), ((0, Rational[1, 2]), (Plus[Rational[1, 2], Times[Complex[0, 1], Global`p, Power[Pi, -1]]],)), Times[Complex[0, Rational[1, 2]], Global`w, Global`x], Rational[1, 2]]]), (Times[Global`q, Hypergeometric2F1[Global`a, Global`b, Global`c, Global`x]], Times[Global`q, Power[Gamma[Global`a], -1], << 1 >>, Gamma[Global`c], Inactive[MeijerG][((Plus[1, Times[-1, Global`a]], Plus[1, Times[-1, Global`b]]), ()), ((0,), (Plus[1, Times[-1, Global`c]],)), Times[-1, Global`x]]]), (Times[Global`a, UnitStep[Times[Global`w, Global`x]]], ConditionalExpression[Times[Global`a, Inactive[MeijerG][((1,), ()), ((), (0,)), Plus[1, Times[Global`w, Global`x]]]], Greater[Times[Global`w, Global`x], -2]]), (Times[Global`a, UnitBox[Times[Global`w, Global`x]]], Times[Global`a, Inactive[MeijerG][((), (1,)), ((0,), ()), Times[2, Global`w, Global`x]]]), (Times[Global`x, UnitStep[Global`x]], ConditionalExpression[Times[Global`x, Inactive[MeijerG][((1,), ()), ((), (0,)), Plus[1, Global`x]]], Greater[Global`x, -2]])), Rule[Background, (None, ((None, GrayLevel[0.9]),), (Rule[(1, 1), Hue[0.6, 0.4, 1]], Rule[(1, 2), Hue[0.6, 0.4, 1]]))], << 2 >>, Rule[FrameStyle, Hue[0.6, 0.4, 0.8]], Rule[Spacings, (2, 1)]]
